# %%
import sys
sys.path.append("..")
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/cces18_common_vv.csv')
# Out:
# c:\users\tomas\.virtualenvs\datascrapper2-nhmyotxb\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (283,290,464,471) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#           caseid  commonweight  commonpostweight  vvweight  vvweight_post  \
# 0      123464282      0.940543            0.7936  0.740858       0.641412
# 1      170169205      0.769724            0.7388  0.425236       0.415134
# 2      175996005      1.491642            1.3105  1.700094       1.603264
# 3      176818556      5.104709            4.6304  5.946729       5.658840
# 4      202120533      0.466526            0.3745  0.412451       0.422327
# ...          ...           ...               ...       ...            ...
# 59995  420441626      1.457952            2.2857  1.067382       1.256993
# 59996  420441704      1.530062            1.4626  1.277186       1.182071
# 59997  420445919      0.607522               NaN  0.597612            NaN
# 59998  420449977      0.815931            1.1495       NaN            NaN
# 59999  420450972      0.889778               NaN       NaN            NaN
#
#        tookpost  CCEStake  birthyr  gender  educ  ...  CL_party CL_2018gvm  \
# ...

# %%
from scipy import stats
import sklearn
from sklearn.linear_model import LinearRegression
import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.formula.api import logit
from statsmodels.formula.api import mnlogit
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ind = 'CC18_320c' # Gun control - Ban assault rifles
model = str("CC18_317 ~ %s" % (ind))
voting_model = mnlogit(model, data = data).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.861903
#          Iterations 8

# %%
voting_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ...
# Dep. Variable:               CC18_317   No. Observations:                46172
# Model:                        MNLogit   Df Residuals:                    46164
# Method:                           MLE   Df Model:                            4
# Date:                Sat, 09 May 2020   Pseudo R-squ.:                  0.1487
# Time:                        15:53:52   Log-Likelihood:                -39796.
# converged:                       True   LL-Null:                       -46746.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
# CC18_317=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.8128      0.037    103.878      0.000       3.741       3.885
# CC18_320c     -2.8094      0.028   -100.268      0.000      -2.864      -2.755
# ...

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(voting_model, ind , fig=fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-9d10379a39e3> in <module>
#       1 fig = plt.figure(figsize=(15,8))
# ----> 2 fig = sm.graphics.plot_regress_exog(voting_model, ind , fig=fig)
#
# c:\users\tomas\.virtualenvs\datascrapper2-nhmyotxb\lib\site-packages\statsmodels\graphics\regressionplots.py in plot_regress_exog(results, exog_idx, fig)
#     224     y_name = results.model.endog_names
#     225     x1 = results.model.exog[:, exog_idx]
# --> 226     prstd, iv_l, iv_u = wls_prediction_std(results)
#     227
#     228     ax = fig.add_subplot(2, 2, 1)
#
# c:\users\tomas\.virtualenvs\datascrapper2-nhmyotxb\lib\site-packages\statsmodels\sandbox\regression\predstd.py in wls_prediction_std(res, exog, weights, alpha)
#      77         predicted = res.fittedvalues
#      78         if weights is None:
# ---> 79             weights = res.model.weights
# ...

# %%
data['CC18_317']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        2.0
#         ...
# 59995    2.0
# 59996    1.0
# 59997    2.0
# 59998    1.0
# 59999    1.0
# Name: CC18_317, Length: 60000, dtype: float64

# %%
data
# Out:
#           caseid  commonweight  commonpostweight  vvweight  vvweight_post  \
# 0      123464282      0.940543            0.7936  0.740858       0.641412
# 1      170169205      0.769724            0.7388  0.425236       0.415134
# 2      175996005      1.491642            1.3105  1.700094       1.603264
# 3      176818556      5.104709            4.6304  5.946729       5.658840
# 4      202120533      0.466526            0.3745  0.412451       0.422327
# ...          ...           ...               ...       ...            ...
# 59995  420441626      1.457952            2.2857  1.067382       1.256993
# 59996  420441704      1.530062            1.4626  1.277186       1.182071
# 59997  420445919      0.607522               NaN  0.597612            NaN
# 59998  420449977      0.815931            1.1495       NaN            NaN
# 59999  420450972      0.889778               NaN       NaN            NaN
#
#        tookpost  CCEStake  birthyr  gender  educ  ...  CL_party CL_2018gvm  \
# ...
