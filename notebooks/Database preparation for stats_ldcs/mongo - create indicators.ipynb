# %%
import sys
sys.path.append("../..")
import urllib
from get_wb_data import *
from get_imf_data import *
get_wb_data()
get_imf_data()
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Input In [3], in <module>
#       4 from get_wb_data import *
#       5 from get_imf_data import *
# ----> 6 get_wb_data()
#       7 get_imf_data()
#
# File ~\datascrapper2\notebooks\Database preparation for stats_ldcs\../..\get_wb_data.py:111, in get_wb_data()
#     108     ddata = process_wb_data(data['data'])
#     109     time.sleep(1)
# --> 111     db["indicators"].update_one({ "name" : data['name']},
#     112                 {"$set":{"name" : data['name'],
#     113                             "aggregation": ind["aggregation"],
#     114                             "weight": ind["weight"],
#     115                             "description" : data['description'],
#     116                             "years" : years,
#     117                             "sourceNote" : data['sourcenote'],
# ...
