# %%
import sys
sys.path.append("../..")
import json
import urllib.request
from IPython.display import clear_output
import sources
from geo.countries import Countries
from data.Frame import Frame
from data.Row import Row
from data.Cell import Cell
from data.Stats import calculate_weighted_average as wa
c = Countries()
from sources.worldbank.indicators import get_data_frame_wide as getdfw
import csv
import pandas as pd

# %%
c.load_wb()
ldcs = c.get_group("LDCs")
names = ldcs.get_names_and_aliases()
data = pd.read_csv('ucpd-prio-database.csv')
names.append("Yemen (North Yemen)")
names.append("DR Congo (Zaire)")
names.append("Myanmar (Burma)")

# %%
len(data[data['country'].isin(names)]['country'].unique())
# Out:
# 24

# %%
data
# Out:
#            id                 relid  year  active_year code_status  \
# 0      274152      SOM-2019-1-750-0  2019         True       Clear
# 1      274186      SOM-2019-1-750-1  2019         True       Clear
# 2      274187      SOM-2019-1-750-2  2019         True       Clear
# 3      274335    LIB-2019-2-14746-0  2019         True       Clear
# 4      274392      AFG-2019-1-735-0  2019         True       Clear
# ...       ...                   ...   ...          ...         ...
# 12479  336233  GUA-2019-2-14799-229  2019         True       Clear
# 12480  336234  GUA-2019-2-14799-230  2019         True       Clear
# 12481  336235  GUA-2019-2-14799-231  2019         True       Clear
# 12482  336236  GUA-2019-2-14799-232  2019         True       Clear
# 12483  336237  GUA-2019-2-14799-233  2019         True       Clear
#
#        type_of_violence  conflict_dset_id  conflict_new_id  \
# 0                     1               337              337
# ...
