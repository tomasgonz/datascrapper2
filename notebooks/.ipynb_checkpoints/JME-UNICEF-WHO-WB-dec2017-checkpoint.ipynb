# %%
import sys
sys.path.append("..")
import csv
import json
import urllib.request
from IPython.display import clear_output
import sources
from countrylist import CountryList
from data.Frame import Frame
from data.Row import Row
from data.Cell import Cell
from data.Stats import calculate_weighted_average as wa
c = CountryList()
c.load_wb()
from sources.worldbank.indicators import get_data_frame_wide as getdfw

# %%
column_names = []
df = Frame()
with open('jme-dec-2017.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='"')
    i = next(reader)
    for col in i:
        column_names.append(col)
    
    column_names[0] = 'iso3code'
    
    for r in reader:
        dr = Row()
        for i in range(0,len(r)):
            dr.cells.append(Cell(column=column_names[i], value=r[i]))
        
        df.rows.append(dr)

# %%
groups=[['LDCs', 'Africa'],['LDCs', 'Asia and the Pacific'],['LDCs', 'America']]

# %%
# We will store the final result here
ndf = Frame()
# Let's prepare the data to be properly formatted by region

for g in groups:              
    for ctry in c.get_groups(g):                
        years = []
        for r in df.search("iso3code", ctry.iso3code).rows:
            years.append(r.get_by_column_name('year').value.value)                               
        
        tdf = Frame()
        #tdf.rows = df.search("iso3code", ctry.iso3code).rows
        
        #ndf.rows.append(tdf.search("year", sorted(years)[len(years)-1]).rows[0])
        for r in df.search("iso3code", ctry.iso3code).rows:
            ndf.rows.append(r)

# %%
len(ndf.rows)
# Out:
# 47

# %%
ndf.name = 'jme-dec-2017-ldcs'
ndf.to_xlsx()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-341782f5f65c> in <module>()
#       1 ndf.name = 'jme-dec-2017-ldcs'
# ----> 2 ndf.to_xlsx()
#
# C:\Users\tomas\Dropbox\Coding\datascrapper2\data\Frame.py in to_xlsx(self)
#     172                 j = 0
#     173
# --> 174                 for c in self.column_names():
#     175                         ws.write(i, j, c)
#     176                         j=j+1
#
# C:\Users\tomas\Dropbox\Coding\datascrapper2\data\Frame.py in column_names(self)
#      17                 cols = []
#      18                 r = self.rows[0]
# ---> 19                 for c in r.cells:
#      20                         cols.append(c.column.name)
#      21                 return cols
#
# AttributeError: 'list' object has no attribute 'cells'

# %%
sorted(years)[len(years)-2]

# %%
df.to_xlsx()

# %%
ndf.rows
# Out:
# [[<data.Row.Row at 0x1b6664dcba8>,
#   <data.Row.Row at 0x1b6664dfdd8>,
#   <data.Row.Row at 0x1b6664e9048>],
#  [<data.Row.Row at 0x1b6666e39b0>,
#   <data.Row.Row at 0x1b6666e8c18>,
#   <data.Row.Row at 0x1b6666eadd8>,
#   <data.Row.Row at 0x1b6666f2080>,
#   <data.Row.Row at 0x1b6666f52b0>],
#  [<data.Row.Row at 0x1b666654940>,
#   <data.Row.Row at 0x1b666657b38>,
#   <data.Row.Row at 0x1b666659da0>,
#   <data.Row.Row at 0x1b66665dfd0>],
#  [<data.Row.Row at 0x1b6666c4630>,
#   <data.Row.Row at 0x1b6666c8860>,
#   <data.Row.Row at 0x1b6666cba90>,
#   <data.Row.Row at 0x1b6666cecc0>,
#   <data.Row.Row at 0x1b6666d2eb8>,
#   <data.Row.Row at 0x1b6666d9128>,
#   <data.Row.Row at 0x1b6666db320>,
#   <data.Row.Row at 0x1b6666de518>,
#   <data.Row.Row at 0x1b6666e2748>],
#  [<data.Row.Row at 0x1b666731400>,
#   <data.Row.Row at 0x1b666734668>,
#   <data.Row.Row at 0x1b6667388d0>,
#   <data.Row.Row at 0x1b66673bb38>],
#  [<data.Row.Row at 0x1b6668419e8>,
#   <data.Row.Row at 0x1b666843c18>,
#   <data.Row.Row at 0x1b666846e48>,
#   <data.Row.Row at 0x1b66684d0b8>,
#   <data.Row.Row at 0x1b6668512e8>],
#  [<data.Row.Row at 0x1b6667cce10>,
#   <data.Row.Row at 0x1b6667d30b8>,
#   <data.Row.Row at 0x1b6667d7320>,
#   <data.Row.Row at 0x1b6667d9588>],
#  [<data.Row.Row at 0x1b6668534e0>,
#   <data.Row.Row at 0x1b6668566a0>,
#   <data.Row.Row at 0x1b66685a908>,
#   <data.Row.Row at 0x1b66685eb70>,
#   <data.Row.Row at 0x1b666861dd8>],
#  [<data.Row.Row at 0x1b6668e05f8>,
#   <data.Row.Row at 0x1b6668e3898>,
#   <data.Row.Row at 0x1b6668e6b38>,
#   <data.Row.Row at 0x1b6668e9dd8>],
#  [<data.Row.Row at 0x1b6668ecf98>,
#   <data.Row.Row at 0x1b6668f31d0>,
#   <data.Row.Row at 0x1b6668f6400>,
#   <data.Row.Row at 0x1b6668f9630>,
#   <data.Row.Row at 0x1b6668fd860>,
#   <data.Row.Row at 0x1b666900a90>],
#  [<data.Row.Row at 0x1b66696ccf8>,
#   <data.Row.Row at 0x1b66696ff28>,
#   <data.Row.Row at 0x1b6669751d0>,
#   <data.Row.Row at 0x1b666978400>,
#   <data.Row.Row at 0x1b66697b668>,
#   <data.Row.Row at 0x1b6669808d0>],
#  [<data.Row.Row at 0x1b6669136a0>,
#   <data.Row.Row at 0x1b6669178d0>,
#   <data.Row.Row at 0x1b66691ab38>,
#   <data.Row.Row at 0x1b66691cda0>,
#   <data.Row.Row at 0x1b666923048>],
#  [<data.Row.Row at 0x1b666984b38>,
#   <data.Row.Row at 0x1b666987da0>,
#   <data.Row.Row at 0x1b66698e048>,
#   <data.Row.Row at 0x1b666990240>],
#  [<data.Row.Row at 0x1b666b66898>,
#   <data.Row.Row at 0x1b666b69b00>,
#   <data.Row.Row at 0x1b666b6cd68>,
#   <data.Row.Row at 0x1b666b71fd0>],
#  [<data.Row.Row at 0x1b666b50908>,
#   <data.Row.Row at 0x1b666b53b38>,
#   <data.Row.Row at 0x1b666b57dd8>,
#   <data.Row.Row at 0x1b666b5d0b8>,
#   <data.Row.Row at 0x1b666b60358>,
#   <data.Row.Row at 0x1b666b625f8>],
#  [<data.Row.Row at 0x1b666b7c780>,
#   <data.Row.Row at 0x1b666b7f940>,
#   <data.Row.Row at 0x1b666b82ac8>,
#   <data.Row.Row at 0x1b666b85cf8>,
#   <data.Row.Row at 0x1b666b89f28>,
#   <data.Row.Row at 0x1b666b8f0b8>],
#  [<data.Row.Row at 0x1b666bee358>,
#   <data.Row.Row at 0x1b666bf15c0>,
#   <data.Row.Row at 0x1b666bf5828>,
#   <data.Row.Row at 0x1b666bf8a58>,
#   <data.Row.Row at 0x1b666bfbc50>,
#   <data.Row.Row at 0x1b666bfee80>],
#  [<data.Row.Row at 0x1b666c796d8>,
#   <data.Row.Row at 0x1b666c7c908>,
#   <data.Row.Row at 0x1b666c7fa90>,
#   <data.Row.Row at 0x1b666c82cc0>,
#   <data.Row.Row at 0x1b666c85ef0>,
#   <data.Row.Row at 0x1b666c8b160>],
#  [<data.Row.Row at 0x1b666c05080>,
#   <data.Row.Row at 0x1b666c082b0>,
#   <data.Row.Row at 0x1b666c0b4a8>,
#   <data.Row.Row at 0x1b666c0e710>,
#   <data.Row.Row at 0x1b666c11978>,
#   <data.Row.Row at 0x1b666c14ba8>,
#   <data.Row.Row at 0x1b666c17dd8>,
#   <data.Row.Row at 0x1b666c1e080>,
#   <data.Row.Row at 0x1b666c212b0>],
#  [<data.Row.Row at 0x1b666b92320>,
#   <data.Row.Row at 0x1b666b96518>,
#   <data.Row.Row at 0x1b666b9a710>,
#   <data.Row.Row at 0x1b666b9d978>,
#   <data.Row.Row at 0x1b666ba0be0>,
#   <data.Row.Row at 0x1b666ba3e48>,
#   <data.Row.Row at 0x1b666bab0b8>,
#   <data.Row.Row at 0x1b666bae320>,
#   <data.Row.Row at 0x1b666bb1550>,
#   <data.Row.Row at 0x1b666bb5780>],
#  [<data.Row.Row at 0x1b666cf1f60>,
#   <data.Row.Row at 0x1b666cf6198>,
#   <data.Row.Row at 0x1b666cfa3c8>,
#   <data.Row.Row at 0x1b666cfc5f8>,
#   <data.Row.Row at 0x1b666d00828>,
#   <data.Row.Row at 0x1b666d03a20>,
#   <data.Row.Row at 0x1b666d07be0>],
#  [<data.Row.Row at 0x1b666df2588>,
#   <data.Row.Row at 0x1b666df57b8>,
#   <data.Row.Row at 0x1b666df8a20>,
#   <data.Row.Row at 0x1b666dfbc88>,
#   <data.Row.Row at 0x1b666dfee80>,
#   <data.Row.Row at 0x1b666e06128>,
#   <data.Row.Row at 0x1b666e08320>],
#  [<data.Row.Row at 0x1b666ee1160>,
#   <data.Row.Row at 0x1b666ee5358>,
#   <data.Row.Row at 0x1b666ee8518>],
#  [<data.Row.Row at 0x1b666e31ba8>,
#   <data.Row.Row at 0x1b666e34d30>,
#   <data.Row.Row at 0x1b666e37f28>,
#   <data.Row.Row at 0x1b666e3e128>,
#   <data.Row.Row at 0x1b666e42358>,
#   <data.Row.Row at 0x1b666e445c0>,
#   <data.Row.Row at 0x1b666e48828>,
#   <data.Row.Row at 0x1b666e4ba90>,
#   <data.Row.Row at 0x1b666e4ecf8>,
#   <data.Row.Row at 0x1b666e51f60>,
#   <data.Row.Row at 0x1b666e591d0>,
#   <data.Row.Row at 0x1b666e5b400>],
#  [<data.Row.Row at 0x1b666e73208>,
#   <data.Row.Row at 0x1b666e76400>,
#   <data.Row.Row at 0x1b666e79668>,
#   <data.Row.Row at 0x1b666e7b8d0>,
#   <data.Row.Row at 0x1b666e7fb00>,
#   <data.Row.Row at 0x1b666e82d30>,
#   <data.Row.Row at 0x1b666e85f60>],
#  [<data.Row.Row at 0x1b666e98ac8>,
#   <data.Row.Row at 0x1b666e9cd68>,
#   <data.Row.Row at 0x1b666ea0f98>],
#  [<data.Row.Row at 0x1b666ebad30>, <data.Row.Row at 0x1b666ebef28>],
#  [<data.Row.Row at 0x1b666e17be0>,
#   <data.Row.Row at 0x1b666e19e80>,
#   <data.Row.Row at 0x1b666e1f0b8>,
#   <data.Row.Row at 0x1b666e22320>,
#   <data.Row.Row at 0x1b666e26518>],
#  [<data.Row.Row at 0x1b66673fda0>,
#   <data.Row.Row at 0x1b666745048>,
#   <data.Row.Row at 0x1b6667482b0>,
#   <data.Row.Row at 0x1b66674c518>,
#   <data.Row.Row at 0x1b666750748>],
#  [<data.Row.Row at 0x1b666f75550>,
#   <data.Row.Row at 0x1b666f79748>,
#   <data.Row.Row at 0x1b666f7b9e8>,
#   <data.Row.Row at 0x1b666f7fc88>,
#   <data.Row.Row at 0x1b666f81e80>,
#   <data.Row.Row at 0x1b666f880f0>,
#   <data.Row.Row at 0x1b666f8b320>],
#  [<data.Row.Row at 0x1b666ff4588>,
#   <data.Row.Row at 0x1b666ff8780>,
#   <data.Row.Row at 0x1b666ffc978>,
#   <data.Row.Row at 0x1b666ffeb70>,
#   <data.Row.Row at 0x1b667003d30>,
#   <data.Row.Row at 0x1b667005f60>,
#   <data.Row.Row at 0x1b66700d160>,
#   <data.Row.Row at 0x1b66700f390>,
#   <data.Row.Row at 0x1b667013588>,
#   <data.Row.Row at 0x1b6670157b8>],
#  [<data.Row.Row at 0x1b666fd5128>,
#   <data.Row.Row at 0x1b666fd9320>,
#   <data.Row.Row at 0x1b666fdb550>,
#   <data.Row.Row at 0x1b666fdf7b8>,
#   <data.Row.Row at 0x1b666fe2a20>,
#   <data.Row.Row at 0x1b666fe4c88>,
#   <data.Row.Row at 0x1b666fe8eb8>],
#  [<data.Row.Row at 0x1b667116f60>,
#   <data.Row.Row at 0x1b66711c0f0>,
#   <data.Row.Row at 0x1b667121358>,
#   <data.Row.Row at 0x1b667124588>,
#   <data.Row.Row at 0x1b6671287f0>,
#   <data.Row.Row at 0x1b66712ba58>,
#   <data.Row.Row at 0x1b66712fcc0>],
#  [<data.Row.Row at 0x1b6664e0978>,
#   <data.Row.Row at 0x1b6664ef438>,
#   <data.Row.Row at 0x1b6664facf8>],
#  [<data.Row.Row at 0x1b6665caa20>,
#   <data.Row.Row at 0x1b6665cdc18>,
#   <data.Row.Row at 0x1b6665cfe48>,
#   <data.Row.Row at 0x1b6665d6080>,
#   <data.Row.Row at 0x1b6665da2b0>,
#   <data.Row.Row at 0x1b6665dd4e0>,
#   <data.Row.Row at 0x1b6665e0710>,
#   <data.Row.Row at 0x1b6665e4940>,
#   <data.Row.Row at 0x1b6665e7b70>,
#   <data.Row.Row at 0x1b6665eada0>,
#   <data.Row.Row at 0x1b6665edf98>,
#   <data.Row.Row at 0x1b666614208>,
#   <data.Row.Row at 0x1b666617438>,
#   <data.Row.Row at 0x1b66661a630>,
#   <data.Row.Row at 0x1b66661d828>,
#   <data.Row.Row at 0x1b666621a58>,
#   <data.Row.Row at 0x1b666623c50>,
#   <data.Row.Row at 0x1b666626e80>,
#   <data.Row.Row at 0x1b66662d0f0>,
#   <data.Row.Row at 0x1b666632320>,
#   <data.Row.Row at 0x1b666634518>,
#   <data.Row.Row at 0x1b666637748>,
#   <data.Row.Row at 0x1b66663a978>],
#  [<data.Row.Row at 0x1b666664278>,
#   <data.Row.Row at 0x1b666667518>,
#   <data.Row.Row at 0x1b66666a7b8>,
#   <data.Row.Row at 0x1b66666ea20>],
#  [<data.Row.Row at 0x1b6666fe8d0>,
#   <data.Row.Row at 0x1b666704ac8>,
#   <data.Row.Row at 0x1b666706cf8>,
#   <data.Row.Row at 0x1b666709ef0>,
#   <data.Row.Row at 0x1b666710160>,
#   <data.Row.Row at 0x1b666713358>],
#  [<data.Row.Row at 0x1b666ae5390>, <data.Row.Row at 0x1b666ae9518>],
#  [<data.Row.Row at 0x1b666b37860>,
#   <data.Row.Row at 0x1b666b3aa58>,
#   <data.Row.Row at 0x1b666b3dcc0>,
#   <data.Row.Row at 0x1b666b41f28>,
#   <data.Row.Row at 0x1b666b47198>],
#  [<data.Row.Row at 0x1b666c902e8>,
#   <data.Row.Row at 0x1b666c924e0>,
#   <data.Row.Row at 0x1b666c956d8>,
#   <data.Row.Row at 0x1b666c99860>,
#   <data.Row.Row at 0x1b666c9ca90>,
#   <data.Row.Row at 0x1b666ca0cf8>,
#   <data.Row.Row at 0x1b666ca3f60>,
#   <data.Row.Row at 0x1b666ca8208>,
#   <data.Row.Row at 0x1b666cac438>],
#  [<data.Row.Row at 0x1b666cc32b0>,
#   <data.Row.Row at 0x1b666cc7518>,
#   <data.Row.Row at 0x1b666cc9780>,
#   <data.Row.Row at 0x1b666ccc9e8>,
#   <data.Row.Row at 0x1b666cd1c50>,
#   <data.Row.Row at 0x1b666cd3eb8>,
#   <data.Row.Row at 0x1b666cd9128>,
#   <data.Row.Row at 0x1b666cdc320>],
#  [<data.Row.Row at 0x1b666e8f438>,
#   <data.Row.Row at 0x1b666e926a0>,
#   <data.Row.Row at 0x1b666e948d0>],
#  [<data.Row.Row at 0x1b666f619b0>,
#   <data.Row.Row at 0x1b666f64ba8>,
#   <data.Row.Row at 0x1b666f67da0>,
#   <data.Row.Row at 0x1b666f6e048>,
#   <data.Row.Row at 0x1b666f702b0>],
#  [<data.Row.Row at 0x1b666fcfe80>],
#  [<data.Row.Row at 0x1b66704f898>,
#   <data.Row.Row at 0x1b667053b38>,
#   <data.Row.Row at 0x1b667057dd8>],
#  [<data.Row.Row at 0x1b667100198>,
#   <data.Row.Row at 0x1b6671043c8>,
#   <data.Row.Row at 0x1b667108630>,
#   <data.Row.Row at 0x1b66710b860>,
#   <data.Row.Row at 0x1b66710eac8>,
#   <data.Row.Row at 0x1b667112cf8>],
#  [<data.Row.Row at 0x1b6669a9160>,
#   <data.Row.Row at 0x1b6669ad358>,
#   <data.Row.Row at 0x1b6669b1588>,
#   <data.Row.Row at 0x1b6669b37b8>,
#   <data.Row.Row at 0x1b6669b79e8>]]
