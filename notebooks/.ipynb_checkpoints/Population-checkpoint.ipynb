# %%
import sys
sys.path.append("../")
import pandas as pd
from data import Frame, Row, Column

# %%
df = pd.read_excel('../data/UN_PPP2019_PopTot.xlsx')
df = df.rename(columns={'Region, subregion, country or area': 'entity'})

# %%
tdf = Frame.Frame()
cols = df.columns.values;
for i in range(0,len(df)):
    new_row = {}
    for j in range(0, len(df.columns)):
        new_row[cols[j]]=df.iloc[i,j]
    tdf.add_row(new_row)

# %%
# Out:
#      Index    Variant                                             entity  \
# 0        1  Median PI                                              WORLD
# 1        3  Median PI                             More developed regions
# 2        4  Median PI                             Less developed regions
# 3        5  Median PI                          Least developed countries
# 4        6  Median PI  Less developed regions, excluding least develo...
# ..     ...        ...                                                ...
# 280    285  Median PI                                            Bermuda
# 281    286  Median PI                                             Canada
# 282    287  Median PI                                          Greenland
# 283    288  Median PI                          Saint Pierre and Miquelon
# 284    289  Median PI                           United States of America
#
#     Notes  Unnamed: 4               Type  Unnamed: 6         2020  \
# 0     NaN         900              World           0  7794798.729
# 1       b         901  Development Group        1803  1273304.261
# 2       c         902  Development Group        1803  6521494.468
# 3       d         941  Development Group         902  1057438.163
# 4       e         934  Development Group         902  5464056.305
# ..    ...         ...                ...         ...          ...
# 280    14          60       Country/Area         918       62.273
# 281   NaN         124       Country/Area         918    37742.157
# 282    26         304       Country/Area         918       56.772
# 283     2         666       Country/Area         918        5.795
# 284    35         840       Country/Area         918   331002.647
#
#             2025         2030  ...         2055          2060          2065  \
# 0    8184437.453  8548487.371  ...  9958098.746  1.015147e+07  1.031788e+07
# 1    1281504.463  1286009.879  ...  1273974.218  1.267173e+06  1.260313e+06
# 2    6902932.990  7262477.492  ...  8684124.528  8.884297e+06  9.057567e+06
# 3    1182376.585  1313758.882  ...  2019337.702  2.159628e+06  2.296254e+06
# 4    5720556.405  5948718.610  ...  6664786.826  6.724669e+06  6.761313e+06
# ..           ...          ...  ...          ...           ...           ...
# 280       61.518       60.487  ...       51.038  4.900200e+01  4.721200e+01
# 281    39326.964    40833.733  ...    46704.574  4.777946e+04  4.892486e+04
# 282       57.186       57.092  ...       52.135  5.100400e+01  4.987700e+01
# 283        5.728        5.675  ...        5.054  4.871000e+00  4.710000e+00
# 284   340399.604   349641.876  ...   385334.853  3.914949e+05  3.978761e+05
#
#              2070          2075          2080          2085          2090  \
# 0    1.045924e+07  1.057729e+07  1.067390e+07  1.075066e+07  1.080989e+07
# 1    1.254230e+06  1.249365e+06  1.245980e+06  1.244019e+06  1.243338e+06
# 2    9.205009e+06  9.327923e+06  9.427925e+06  9.506644e+06  9.566554e+06
# 3    2.427682e+06  2.552546e+06  2.669675e+06  2.778054e+06  2.877187e+06
# 4    6.777327e+06  6.775377e+06  6.758250e+06  6.728590e+06  6.689367e+06
# ..            ...           ...           ...           ...           ...
# 280  4.568600e+01  4.423300e+01  4.277700e+01  4.127300e+01  3.974900e+01
# 281  5.009601e+04  5.124046e+04  5.234831e+04  5.343632e+04  5.453954e+04
# 282  4.868200e+01  4.739200e+01  4.602500e+01  4.462500e+01  4.325800e+01
# 283  4.582000e+00  4.463000e+00  4.362000e+00  4.265000e+00  4.175000e+00
# 284  4.041744e+05  4.099926e+05  4.151974e+05  4.199374e+05  4.244699e+05
#
#              2095          2100
# 0    1.085186e+07  1.087539e+07
# 1    1.243595e+06  1.244296e+06
# 2    9.608265e+06  9.631098e+06
# 3    2.966790e+06  3.046779e+06
# 4    6.641475e+06  6.584319e+06
# ..            ...           ...
# 280  3.828100e+01  3.693300e+01
# 281  5.570930e+04  5.695322e+04
# 282  4.188700e+01  4.052400e+01
# 283  4.082000e+00  3.984000e+00
# 284  4.290817e+05  4.338539e+05
#
# [285 rows x 24 columns]
