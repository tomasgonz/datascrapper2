# %%
import sys
sys.path.append("../../")
from data.Frame import Frame
from bk import show_weighted_average, show_group_total, get_pandas_dataframe, line_chart, scatter_plot
from bokeh.io import output_notebook
from bokeh.plotting import figure, output_file, show, reset_output
from sources.unpd.indicators import get_projection_by_groups as gpp
from sources.cdp.indicators import get_indicators as get_indicators_cdp_2018
from pandas import DataFrame
reset_output()
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
cdp_data_2018 = get_indicators_cdp_2018(['LDCs'])
df = DataFrame(columns = cdp_data_2018.get_column_names(), data =cdp_data_2018.as_array())

# %%
# Prevalence of undernourishment (% of population)
years = list(map(str, list(range(2010,2018))))
result = show_weighted_average(years, 'SN.ITK.DEFC.ZS', 'SP.POP.TOTL', 
                               ['LDCs', 'Developing excluding LDCs', 'OECD'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-70e476c76472> in <module>
#       2 years = list(map(str, list(range(2000,2018))))
#       3 result = show_weighted_average(years, 'SN.ITK.DEFC.ZS', 'SP.POP.TOTL',
# ----> 4                                ['LDCs', 'Developing excluding LDCs', 'OECD'])
#
# /mnt/c/Users/Tomas.Gonzalez/datascrapper2/bk.py in show_weighted_average(years, indicator, weight, groups)
#     132         datasets.append([x,y, group, data_group.description])
#     133     series = datasets
# --> 134     show(line_chart(series, series[0][3], x_axis_label="Years", y_axis_label=indicator, height=400, width=800))
#     135
#     136     return series
#
# /mnt/c/Users/Tomas.Gonzalez/datascrapper2/bk.py in line_chart(series, title, **kwargs)
#      45     legend_items = []
#      46
# ...

# %%
import sources
years = list(map(str, list(range(2000,2010))))
maln = sources.worldbank.datatable.get_data_table(years, 'SN.ITK.DEFC.ZS', [['LDCs']])

# %%
datasets = []
cols = maln.get_column_names()[1:len(maln.get_column_names())]
for r in maln.rows:
    x = cols
    y = r.as_array()[1:len(r.as_array())]
    datasets.append([x,y, r.as_array()[0], maln.description])

# %%
from bk import show_line_by_line
result = show_line_by_line(maln, x_axis_label='Countries', 
                y_axis_label='Values', height=2000, width=900)
