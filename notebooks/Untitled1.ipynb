# %%
import sys
sys.path.append("..")
import json
import urllib.request
from IPython.display import clear_output
import sources
from countries.list import CountryList
from countries.utils import extract_countries
from data.Frame import Frame
from data.Row import Row
from data.Cell import Cell
from data.Stats import calculate_weighted_average as wa
c = CountryList()
c.load_wb()
from sources.worldbank.indicators import get_data_frame_wide as getdfw
from sources.worldbank.datatable import get_data_table
years = ["2016"]
groups_ldcs=[['LDCs']]
groups_ldcs2025=[['LDCs2025']]
indicator = 'NV.AGR.TOTL.ZS'
weight = 'NY.GDP.MKTP.KD'
d = get_data_table(years, indicator, [['LDCs']], export_to_excel=False)

# %%
d
# Out:
#  NV.AGR.TOTL.ZS-['2016']-LDCs_
# +------------+------------+
# | entity     | 2016       |
# +------------+------------+
# | Afghanista | 21.081     |
# | n          |            |
# +------------+------------+
# | Angola     | 9.831      |
# +------------+------------+
# | Burundi    | 30.646     |
# +------------+------------+
# | Benin      | 23.240     |
# +------------+------------+
# | Burkina    | 30.757     |
# | Faso       |            |
# +------------+------------+
# | Bangladesh | 14.046     |
# +------------+------------+
# | Bhutan     | 16.644     |
# +------------+------------+
# | Central    | 40.474     |
# | African    |            |
# | Republic   |            |
# +------------+------------+
# | Congo,     | 18.600     |
# | Dem. Rep.  |            |
# +------------+------------+
# | Comoros    | 29.641     |
# +------------+------------+
# | Djibouti   | 1.943      |
# +------------+------------+
# | Eritrea    | None       |
# +------------+------------+
# | Ethiopia   | 34.755     |
# +------------+------------+
# | Guinea     | 17.828     |
# +------------+------------+
# | Gambia,    | 24.957     |
# | The        |            |
# +------------+------------+
# | Guinea-    | 46.348     |
# | Bissau     |            |
# +------------+------------+
# | Haiti      | 17.528     |
# +------------+------------+
# | Cambodia   | 24.743     |
# +------------+------------+
# | Kiribati   | 26.321     |
# +------------+------------+
# | Lao PDR    | 17.230     |
# +------------+------------+
# | Liberia    | 37.242     |
# +------------+------------+
# | Lesotho    | 5.869      |
# +------------+------------+
# | Madagascar | 21.344     |
# +------------+------------+
# | Mali       | 38.368     |
# +------------+------------+
# | Myanmar    | 25.469     |
# +------------+------------+
# | Mozambique | 22.618     |
# +------------+------------+
# | Mauritania | 23.990     |
# +------------+------------+
# | Malawi     | 25.927     |
# +------------+------------+
# | Niger      | 38.784     |
# +------------+------------+
# | Nepal      | 29.149     |
# +------------+------------+
# | Rwanda     | 29.310     |
# +------------+------------+
# | Sudan      | 31.200     |
# +------------+------------+
# | Senegal    | 14.727     |
# +------------+------------+
# | Solomon    | None       |
# | Islands    |            |
# +------------+------------+
# | Sierra     | 58.209     |
# | Leone      |            |
# +------------+------------+
# | Somalia    | None       |
# +------------+------------+
# | South      | None       |
# | Sudan      |            |
# +------------+------------+
# | Sao Tome   | 11.873     |
# | and        |            |
# | Principe   |            |
# +------------+------------+
# | Chad       | 46.126     |
# +------------+------------+
# | Togo       | 40.742     |
# +------------+------------+
# | Timor-     | 11.353     |
# | Leste      |            |
# +------------+------------+
# | Tuvalu     | None       |
# +------------+------------+
# | Tanzania   | 29.234     |
# +------------+------------+
# | Uganda     | 23.654     |
# +------------+------------+
# | Vanuatu    | None       |
# +------------+------------+
# | Yemen,     | 7.092      |
# | Rep.       |            |
# +------------+------------+
# | Zambia     | 6.228      |
# +------------+------------+
